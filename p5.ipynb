# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error


data = load_iris()
df = pd.DataFrame(data.data, columns=data.feature_names)


X = df['petal length (cm)'].values.reshape(-1, 1)
y = df['petal width (cm)'].values


plt.figure(figsize=(8, 6))
plt.scatter(X, y, color='blue')
plt.title('Scatter Plot of Petal Length vs Petal Width')
plt.xlabel('Petal Length (cm)')
plt.ylabel('Petal Width (cm)')
plt.show()


correlation_matrix = df.corr()
print("Correlation Matrix:\n", correlation_matrix)


model = LinearRegression()
model.fit(X, y)


intercept = model.intercept_
slope = model.coef_[0]

print(f"Intercept: {intercept}")
print(f"Slope: {slope}")


y_pred = model.predict(X)


mse = mean_squared_error(y, y_pred)
print(f"Mean Squared Error (MSE): {mse}")



sst = np.sum((y - np.mean(y))**2)


sse = np.sum((y - y_pred)**2)


ssr = np.sum((y_pred - np.mean(y))**2)


r2 = model.score(X, y)

print(f"SST (Total Sum of Squares): {sst}")
print(f"SSE (Sum of Squared Errors): {sse}")
print(f"SSR (Sum of Squares for Regression): {ssr}")
print(f"R² (Coefficient of Determination): {r2}")
# Out:
# Correlation Matrix:
#                     sepal length (cm)  sepal width (cm)  petal length (cm)  \
# sepal length (cm)           1.000000         -0.117570           0.871754
# sepal width (cm)           -0.117570          1.000000          -0.428440
# petal length (cm)           0.871754         -0.428440           1.000000
# petal width (cm)            0.817941         -0.366126           0.962865
#
#                    petal width (cm)
# sepal length (cm)          0.817941
# sepal width (cm)          -0.366126
# petal length (cm)          0.962865
# petal width (cm)           1.000000
# Intercept: -0.3630755213190291
# Slope: 0.41575541635241153
# Mean Squared Error (MSE): 0.04206730919499318
# SST (Total Sum of Squares): 86.56993333333332
# SSE (Sum of Squared Errors): 6.310096379248977
# SSR (Sum of Squares for Regression): 80.25983695408436
# R² (Coefficient of Determination): 0.9271098389904927
